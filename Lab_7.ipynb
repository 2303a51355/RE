# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51355/RE/blob/main/Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 .Undiscounted and Discounted Returns

# %%
n = int(input("Enter number of time steps: "))
rewards = []
for i in range(n):
    r = float(input(f"Enter reward at time step {i+1}: "))
    rewards.append(r)
gamma = float(input("Enter discount factor gamma (γ): "))
undiscounted_return = sum(rewards)
discounted_return = 0
for i in range(n):
    discounted_return += (gamma ** i) * rewards[i]
print("\nEntered reward values:", rewards)
print("Undiscounted Return:", undiscounted_return)
print("Discounted Return:", discounted_return)
# Out:
# Enter number of time steps: 4
# Enter reward at time step 1: 10
# Enter reward at time step 2: 20
# Enter reward at time step 3: 30
# Enter reward at time step 4: 40
# Enter discount factor gamma (γ): 0.9
#
# Entered reward values: [10.0, 20.0, 30.0, 40.0]
# Undiscounted Return: 100.0
# Discounted Return: 81.46000000000001

# %% [markdown]
# 2.

# %%
import grid_env_det as env
print("State Space:")
print(env.states)
print("\nAction Space:")
print(env.actions)
print("\nDiscount Factor:")
print(env.gamma)

print("\n--- Transition Estimation ---")

state = input("Enter current state (S0, S1, S3, S4): ")
action = input("Enter action (up, down, left, right): ")


next_state = env.transition(state, action)
reward = env.reward(next_state)
print("\nCurrent State:", state)
print("Action:", action)
print("Next State:", next_state)
print("Reward:", reward)
# Out:
# State Space:
# ['S0']
#
# Action Space:
# ['up']
#
# Discount Factor:
# 0.9
#
# --- Transition Estimation ---
# Enter current state (S0, S1, S3, S4): s1
# Enter action (up, down, left, right): right
#
# Current State: s1
# Action: right
# Next State: s1
# Reward: 0.0
